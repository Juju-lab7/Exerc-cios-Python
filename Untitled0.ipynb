# %%
Notas = []
contador = 1

while contador < 5:
  Notas.append(float(input(f'Informe a {contador}ª nota:')))
  contador += 1

maior_nota = max(Notas)
menor_nota = min(Notas)
media = sum(Notas) / len(Notas)
# Out:
# Informe a 1ª nota:5
# Informe a 2ª nota:9
# Informe a 3ª nota:10
# Informe a 4ª nota:6

# %%
notas = []
contador = 1
while contador < 5:
    notas.append(int(input(f'Informe a {contador}ª nota:')))
    contador += 1

media = sum(notas) / len(notas)
print(f'Sua média final foi {media}')
if media >= 7:
    print('APROVADO!!')
else:
    notas.append(int(input('Informe a nota da prova final:')))

    media = sum(notas) / len(notas) # Corrected sum typo
    print(f'Parabéns, sua média final foi {media}') # Added {media} to print statement
    if media >= 5:
        print('APROVADO!!')
    else:
        print('REPROVADO...') # Corrected closing quote
# Out:
# Informe a 1ª nota:8
# Informe a 2ª nota:6
# Informe a 3ª nota:7
# Informe a 4ª nota:10
# Sua média final foi 7.75
# APROVADO!!
